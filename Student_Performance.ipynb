# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Loading CSV File in Pandas Data Frame

# %%
stud_mat = pd.read_csv('student-mat.csv',sep=';')

# %% [markdown]
# ## Taking Look at the Data

# %%
print ('Number of Rows:', stud_mat.shape[0])
print ('Number of Columns:', stud_mat.shape[1])

stud_mat.head()
# Out:
# Number of Rows: 395
# Number of Columns: 33
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Checking Null Values

# %%
stud_mat.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# #### There are No Missing Values in Data
# #### Our data is Clean

# %% [markdown]
# ### Statistics of Data

# %%
stud_mat.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# ### Checking Data Type of Each Column

# %%
stud_mat.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# #### We got familiar with data Numerically

# %% [markdown]
# ## Simple Exploratory Data Analysis

# %% [markdown]
# #### Lets take a look at Final Grades 'G3'

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.bar(stud_mat['G3'].value_counts().index,stud_mat['G3'].value_counts().values,fill = 'navy', edgecolor = 'k', width = 1)
plt.xlabel('G3'); plt.ylabel('Count'); plt.title('Distribution of Final Grades');
plt.xticks(list(range(0, 21)));

# %% [markdown]
# ### Findings:
# #### Final Grades are pretty much Normally Distributed

# %% [markdown]
# ### Now it's Time to Find more Insights by Visualizing it.
#
# #### We going to Visualize each column with respect to our Target (Response) i.e. 'G3'.
# #### This approach will help us to understand relation between each column & Target.

# %% [markdown]
# ### School Column

# %%
df_sch=stud_mat[['G3','school']].copy()

df_sch1=df_sch.groupby(['school']).count()

df_sch2=df_sch.groupby(['school']).mean()

print ('Number of Students from each School\n', df_sch1.head())
print ('\nAverage Final Grade of Students from each School\n',df_sch2.head(),'\n\n')


#Plot

ax1 = df_sch1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("School (GP/MS) vs Students", fontsize=15)
ax1.set_xlabel("GP & MS", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_sch2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("School (GP/MS) vs Average G3", fontsize=15)
ax2.set_xlabel("School", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students from each School
#           G3
# school
# GP      349
# MS       46
#
# Average Final Grade of Students from each School
#                 G3
# school
# GP      10.489971
# MS       9.847826

# %% [markdown]
# ### Findings:
# #### Number of Students from 'GP' (Gabriel Pereira) School are more than 'MS' (Mousinho da Silveira) School.
# #### Average of Final Grades of Students from 'GP' (Gabriel Pereira) School is more than 'MS' (Mousinho da Silveira) School.

# %% [markdown]
# ### Sex Column

# %%
df_sex=stud_mat[['G3','sex']].copy()

df_sex1=df_sex.groupby(['sex']).count()

df_sex2=df_sex.groupby(['sex']).mean()

print ('Number of Students with Respect to Sex\n', df_sex1.head())
print ('\nAverage Final Grade of Students with Respect to Sex\n',df_sex2.head(),'\n\n')


#Plot

ax1 = df_sex1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Sex (F/M) vs Students", fontsize=15)
ax1.set_xlabel("Female & Male", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_sex2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Sex (F/M) vs Average G3", fontsize=15)
ax2.set_xlabel("Sex", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Sex
#        G3
# sex
# F    208
# M    187
#
# Average Final Grade of Students with Respect to Sex
#              G3
# sex
# F     9.966346
# M    10.914439

# %% [markdown]
# ### Findings:
# #### Number of Female 'F' Students are more than  Male 'M' Students..
# #### Average of Final Grades of Male Students is more than Female Students.

# %% [markdown]
# ### Age Column

# %%
df_age=stud_mat[['G3','age']].copy()

df_age1=df_age.groupby(['age']).count()

df_age2=df_age.groupby(['age']).mean()

print ('Number of Students with Respect to Age\n', df_age1)
print ('\nAverage Final Grade of Students with Respect to Age\n',df_age2,'\n\n')



#Plot Age
plt.rcParams['figure.figsize'] = [8, 5]
plt.plot(df_age1)
plt.title('Age vs Students',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('No. Students',fontsize=12)

ax2 = df_age2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Student Age vs Average G3", fontsize=15)
ax2.set_xlabel("Age", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Age
#        G3
# age
# 15    82
# 16   104
# 17    98
# 18    82
# 19    24
# 20     3
# 21     1
# 22     1
#
# Average Final Grade of Students with Respect to Age
#              G3
# age
# 15   11.256098
# 16   11.028846
# 17   10.275510
# 18    9.548780
# 19    8.208333
# 20   14.000000
# 21    7.000000
# 22    8.000000

# %% [markdown]
# ### Findings:
# #### As Age increases Number of Students Decreases which states that Age is inversely proportional to No. of Students.
# #### Also Age is negatively correlated to Average of Final Grades.
# #### At Age 20 & 22 there is sudden rise in Avg. G3, but if we look at No. of students with Age 20 & 22 then there are only 4. Hence we can treat them as a outliers.

# %% [markdown]
# ### Address Column

# %%
df_add=stud_mat[['G3','address']].copy()

df_add1=df_add.groupby(['address']).count()

df_add2=df_add.groupby(['address']).mean()

print ('Number of Students From Urban & Rural\n', df_add1.head())
print ('\nAverage Final Grade of Students From Urban & Rural\n',df_add2.head(),'\n\n')


#Plot

ax1 = df_add1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Address (R/U) vs Students", fontsize=15)
ax1.set_xlabel("Urban & Rural", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_add2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Address (R/U) vs Average G3", fontsize=15)
ax2.set_xlabel("adress", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students From Urban & Rural
#            G3
# address
# R         88
# U        307
#
# Average Final Grade of Students From Urban & Rural
#                  G3
# address
# R         9.511364
# U        10.674267

# %% [markdown]
# ### Findings:
# #### Number of Students from Urban 'U' are more than  Rural 'R' Students..
# #### Average of Final Grades of Urban Students is more than Rural Students.

# %% [markdown]
# ### Family Size Column

# %%
df_fsz=stud_mat[['G3','famsize']].copy()

df_fsz1=df_fsz.groupby(['famsize']).count()

df_fsz2=df_fsz.groupby(['famsize']).mean()

print ('Number of Students with Respect to Family Size\n', df_fsz1.head())
print ('\nAverage Final Grade of Students with Respect to Family Size\n',df_fsz2.head(),'\n\n')


#Plot

ax1 = df_fsz1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Family Size (LE3/GT3) vs Students", fontsize=15)
ax1.set_xlabel("famsize", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_fsz2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Family Size (LE3/GT3 vs Average G3", fontsize=15)
ax2.set_xlabel("famsize", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Family Size
#            G3
# famsize
# GT3      281
# LE3      114
#
# Average Final Grade of Students with Respect to Family Size
#                  G3
# famsize
# GT3      10.177936
# LE3      11.000000

# %% [markdown]
# ### Findings:
# #### Number of Students from Families Greater than 3 'GT3' are more than  Families less than 3 'LE3'.
# #### Average of Final Grades of 'LE3' Students is more than 'GT3' Students.

# %% [markdown]
# ### Pstatus Column

# %%
df_pst=stud_mat[['G3','Pstatus']].copy()

df_pst1=df_pst.groupby(['Pstatus']).count()

df_pst2=df_pst.groupby(['Pstatus']).mean()

print ('Number of Students with Respect to Parents Cohabitation Status\n', df_pst1)
print ('\nAverage Final Grade of Students with Respect to Parents Cohabitation Status\n',df_pst2,'\n\n')


#Plot

ax1 = df_pst1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Parents Status (T/A) vs Students", fontsize=15)
ax1.set_xlabel("Pstatus", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_pst2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Parents Status (T/A) vs Average G3", fontsize=15)
ax2.set_xlabel("Pstatus", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Parents Cohabitation Status
#            G3
# Pstatus
# A         41
# T        354
#
# Average Final Grade of Students with Respect to Parents Cohabitation Status
#                  G3
# Pstatus
# A        11.195122
# T        10.324859

# %% [markdown]
# ### Findings:
# #### Number of Students whose Parents cohabitate Together 'T' are more than Parents cohabitate Alone 'A'.
# #### Average of Final Grades of 'A' Students is more than 'T' Students.

# %% [markdown]
# ### Fedu Column

# %%
df_fedu=stud_mat[['G3','Fedu']].copy()

df_fedu2=df_fedu.groupby(['Fedu']).mean()
df_fedu1=df_fedu.groupby(['Fedu']).count()

print ('Number of Students with Respect to Father Education Level\n',df_fedu1)
print ('\nAverage Final Grade of Students with Respect to Father Education Level\n',df_fedu2,'\n\n')


#Plot

plt.plot(df_fedu1)
plt.title('Father Education vs No. Students', fontsize=15)
plt.xlabel('Fedu', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_fedu2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Father Education vs Average G3', fontsize=15)
ax2.set_xlabel("Fedu", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Father Education Level
#         G3
# Fedu
# 0       2
# 1      82
# 2     115
# 3     100
# 4      96
#
# Average Final Grade of Students with Respect to Father Education Level
#               G3
# Fedu
# 0     13.000000
# 1      9.158537
# 2     10.260870
# 3     10.660000
# 4     11.364583

# %% [markdown]
# ### Findings:
# #### As Father Education level increases Number of Students Increases which states that Fedu is Directly proportional to No. of Students.
# #### Also Fedu is Positively correlated to Average of Final Grades.
# #### At Fedu 0 there is sudden rise in Avg. G3, but if we look at No. of students whose Fedu is 0 then there are only 2 Students. Hence we can treat them as a outliers.

# %% [markdown]
# ### Medu

# %%
df_medu=stud_mat[['G3','Medu']].copy()

df_medu1=df_medu.groupby(['Medu']).count()
df_medu2=df_medu.groupby(['Medu']).mean()

print ('Number of Students with Respect to Mother Education Level\n',df_medu1)
print ('\nAverage Final Grade of Students with Respect to Mother Education Level\n',df_medu2,'\n\n')


#Plot

plt.plot(df_medu1)
plt.title('Mother Education vs No. Students', fontsize=15)
plt.xlabel('Medu', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_medu2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Mother Education vs Average G3', fontsize=15)
ax2.set_xlabel("Medu", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Mother Education Level
#         G3
# Medu
# 0       3
# 1      59
# 2     103
# 3      99
# 4     131
#
# Average Final Grade of Students with Respect to Mother Education Level
#               G3
# Medu
# 0     13.000000
# 1      8.677966
# 2      9.728155
# 3     10.303030
# 4     11.763359

# %% [markdown]
# ### Findings:
# #### As Mother Education level increases Number of Students Increases which states that Medu is Directly proportional to No. of Students.
# #### Also Medu is Positively correlated to Average of Final Grades.
# #### At Medu 0 there is sudden rise in Avg. G3, but if we look at No. of students whose Medu is 0 then there are only 3 Students. Hence we can treat them as a outliers.

# %% [markdown]
# ### Mjob Column

# %%
df_mjob=stud_mat[['G3','Mjob']].copy()

df_mjob1=df_mjob.groupby(['Mjob']).count()
df_mjob2=df_mjob.groupby(['Mjob']).mean()

print ('Number of Students with Respect to Mother Job Type\n',df_mjob1)
print ('\nAverage Final Grade of Students with Respect to Mother Job Type\n',df_mjob2,'\n\n')


#Plot

plt.plot(df_mjob1)
plt.title('Mother Job Type vs No. Students', fontsize=15)
plt.xlabel('Mjob', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_mjob2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Mother Job Type vs Average G3', fontsize=15)
ax2.set_xlabel("Mjob", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Mother Job Type
#             G3
# Mjob
# at_home    59
# health     34
# other     141
# services  103
# teacher    58
#
# Average Final Grade of Students with Respect to Mother Job Type
#                   G3
# Mjob
# at_home    9.152542
# health    12.147059
# other      9.822695
# services  11.019417
# teacher   11.051724

# %% [markdown]
# ### Findings:
# #### Average Final Grades of Students whose Mother Job is 'Health' is High, Followed by 'Teacher' as compared to other Job type.

# %% [markdown]
# ### Fjob Column

# %%
df_fjob=stud_mat[['G3','Fjob']].copy()

df_fjob1=df_fjob.groupby(['Fjob']).count()
df_fjob2=df_fjob.groupby(['Fjob']).mean()

print ('Number of Students with Respect to Father Job Type\n',df_fjob1)
print ('\nAverage Final Grade of Students with Respect to Father Job Type\n',df_fjob2,'\n\n')


#Plot

plt.plot(df_fjob1)
plt.title('Father Job Type vs No. Students', fontsize=15)
plt.xlabel('Fjob', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_fjob2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Father Job Type vs Average G3', fontsize=15)
ax2.set_xlabel("Fjob", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Father Job Type
#             G3
# Fjob
# at_home    20
# health     18
# other     217
# services  111
# teacher    29
#
# Average Final Grade of Students with Respect to Father Job Type
#                   G3
# Fjob
# at_home   10.150000
# health    11.611111
# other     10.193548
# services  10.297297
# teacher   11.965517

# %% [markdown]
# ### Findings:
# #### Average Final Grades of Students whose Father Job is 'Teacher' is High, Followed by 'Health' as compared to other Job type.

# %% [markdown]
# ### Reason Column

# %%
df_rsn=stud_mat[['G3','reason']].copy()

df_rsn1=df_rsn.groupby(['reason']).count()
df_rsn2=df_rsn.groupby(['reason']).mean()

print ('Number of Students with Respect to Reason\n',df_rsn1)
print ('\nAverage Final Grade of Students with Respect to Reason\n',df_rsn2,'\n\n')


#Plot

plt.plot(df_rsn1)
plt.title('Reason vs No. Students', fontsize=15)
plt.xlabel('reason', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_rsn2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Reason vs Average G3', fontsize=15)
ax2.set_xlabel("reason", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Reason
#               G3
# reason
# course      145
# home        109
# other        36
# reputation  105
#
# Average Final Grade of Students with Respect to Reason
#                     G3
# reason
# course       9.820690
# home        10.256881
# other       11.166667
# reputation  11.142857

# %% [markdown]
# ### Findings:
# #### Students are more attracted towards Course offered by school followed by distance between School & Home.
# #### Average final grade of reason 'other' & Reputation of School is high as compared to reason 'home' & 'course'.

# %% [markdown]
# ### Guardian Column

# %%
df_guar=stud_mat[['G3','guardian']].copy()

df_guar1=df_guar.groupby(['guardian']).count()
df_guar2=df_guar.groupby(['guardian']).mean()

print ('Number of Students with Respect to Guardian\n',df_guar1)
print ('\nAverage Final Grade of Students with Respect to Guardian\n',df_guar2,'\n\n')


#Plot

plt.plot(df_guar1)
plt.title('Guardian vs No. Students', fontsize=15)
plt.xlabel('guardian', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_guar2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Guardian vs Average G3', fontsize=15)
ax2.set_xlabel("guardian", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Guardian
#             G3
# guardian
# father     90
# mother    273
# other      32
#
# Average Final Grade of Students with Respect to Guardian
#                   G3
# guardian
# father    10.688889
# mother    10.483516
# other      9.062500

# %% [markdown]
# ### Findings:
# #### Number of students whose guardian is Mother  are more than Father & Other.
# #### Average Final grade of student with guardian Father is high than Mother guardian.

# %% [markdown]
# ### Travel Time Column

# %%
df_ttm=stud_mat[['G3','traveltime']].copy()

df_ttm1=df_ttm.groupby(['traveltime']).count()
df_ttm2=df_ttm.groupby(['traveltime']).mean()

print ('Number of Students with Respect to Travel Time\n',df_ttm1)
print ('\nAverage Final Grade of Students with Respect to Travel Time\n',df_ttm2,'\n\n')


#Plot

plt.plot(df_ttm1)
plt.title('Travel Time vs No. Students', fontsize=15)
plt.xlabel('traveltime', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_ttm2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Travel Time vs Average G3', fontsize=15)
ax2.set_xlabel("traveltime", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Travel Time
#               G3
# traveltime
# 1           257
# 2           107
# 3            23
# 4             8
#
# Average Final Grade of Students with Respect to Travel Time
#                     G3
# traveltime
# 1           10.782101
# 2            9.906542
# 3            9.260870
# 4            8.750000

# %% [markdown]
# ### Findings:
# #### As Travel time increses Number of Students Decreases, which states that Travel time is negatively Proportional.
# #### Also Travel time is negatively correlated to Average Final Grades.

# %% [markdown]
# ### Study Time Column

# %%
df_stm=stud_mat[['G3','studytime']].copy()

df_stm1=df_stm.groupby(['studytime']).count()
df_stm2=df_stm.groupby(['studytime']).mean()

print ('Number of Students with Respect to Study Time\n',df_stm1)
print ('\nAverage Final Grade of Students with Respect to Study Time\n',df_stm2,'\n\n')


#Plot

plt.plot(df_stm1)
plt.title('Study Time vs No. Students', fontsize=15)
plt.xlabel('studytime', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_stm2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Study Time vs Average G3', fontsize=15)
ax2.set_xlabel("studytime", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Study Time
#              G3
# studytime
# 1          105
# 2          198
# 3           65
# 4           27
#
# Average Final Grade of Students with Respect to Study Time
#                    G3
# studytime
# 1          10.047619
# 2          10.171717
# 3          11.400000
# 4          11.259259

# %% [markdown]
# ### Findings:
# #### Number of students are more whose study for 2-5 hrs. followed by >2 hrs.
# #### Average Final grade is positively correlated with syudy time.

# %% [markdown]
# ### Failures Column

# %%
df_fail=stud_mat[['G3','failures']].copy()

df_fail1=df_fail.groupby(['failures']).count()
df_fail2=df_fail.groupby(['failures']).mean()

print ('Number of Students with Respect to Failures\n',df_fail1)
print ('\nAverage Final Grade of Students with Respect to Failures\n',df_fail2,'\n\n')


#Plot

plt.plot(df_fail1)
plt.title('Failures vs No. Students', fontsize=15)
plt.xlabel('failures', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_fail2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Failures vs Average G3', fontsize=15)
ax2.set_xlabel("failures", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Failures
#             G3
# failures
# 0         312
# 1          50
# 2          17
# 3          16
#
# Average Final Grade of Students with Respect to Failures
#                   G3
# failures
# 0         11.253205
# 1          8.120000
# 2          6.235294
# 3          5.687500

# %% [markdown]
# ### Findings:
# #### Number of students who never failed are high as compare to '1', '2' & '3'.
# #### Average of final grades is Negatively correlated to Failures.

# %% [markdown]
# ### School Support Column

# %%
df_ssup=stud_mat[['G3','schoolsup']].copy()

df_ssup1=df_ssup.groupby(['schoolsup']).count()

df_ssup2=df_ssup.groupby(['schoolsup']).mean()

print ('Number of Students with Respect to Extra Educational Support\n', df_ssup1)
print ('\nAverage Final Grade of Students with Respect to Extra Educational Support\n',df_ssup2,'\n\n')


#Plot

ax1 = df_ssup1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Extra Education Support vs Students", fontsize=15)
ax1.set_xlabel("school support", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_ssup2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Extra Education Support vs Average G3", fontsize=15)
ax2.set_xlabel("school support", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Extra Educational Support
#              G3
# schoolsup
# no         344
# yes         51
#
# Average Final Grade of Students with Respect to Extra Educational Support
#                    G3
# schoolsup
# no         10.561047
# yes         9.431373

# %% [markdown]
# ### Findings:
# #### Number of students with No Extra school support are more than students with Extra school support.
# #### Average of Final Grades is high for students without extra school support as compared to students with extra support.

# %% [markdown]
# ### Family Support Column

# %%
df_fsup=stud_mat[['G3','famsup']].copy()

df_fsup1=df_fsup.groupby(['famsup']).count()

df_fsup2=df_fsup.groupby(['famsup']).mean()

print ('Number of Students with Respect to Family Support\n', df_fsup1)
print ('\nAverage Final Grade of Students with Respect to Family Support\n',df_fsup2,'\n\n')


#Plot

ax1 = df_fsup1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Family Support vs Students", fontsize=15)
ax1.set_xlabel("Family support", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_fsup2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Family Support vs Average G3", fontsize=15)
ax2.set_xlabel("family support", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Family Support
#           G3
# famsup
# no      153
# yes     242
#
# Average Final Grade of Students with Respect to Family Support
#                 G3
# famsup
# no      10.640523
# yes     10.272727

# %% [markdown]
# ### Findings:
# #### Number of students with Family support are more than students without Family support.
# #### Average of Final Grades is slightly high for students without family support as compared to students with family support.

# %% [markdown]
# ### Paid Subject Column

# %%
df_paid=stud_mat[['G3','paid']].copy()

df_paid1=df_paid.groupby(['paid']).count()

df_paid2=df_paid.groupby(['paid']).mean()

print ('Number of Students with Respect to EXtra Paid Classes \n', df_paid1)
print ('\nAverage Final Grade of Students with Respect to Extra paid Classes\n',df_paid2,'\n\n')


#Plot

ax1 = df_paid1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Paid Extra Classes vs Students", fontsize=15)
ax1.set_xlabel("paid classes", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_paid2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Paid Extra Classes vs Average G3", fontsize=15)
ax2.set_xlabel("paid classes", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to EXtra Paid Classes
#         G3
# paid
# no    214
# yes   181
#
# Average Final Grade of Students with Respect to Extra paid Classes
#               G3
# paid
# no     9.985981
# yes   10.922652

# %% [markdown]
# ### Findings:
# #### Number of students without Paid classes are more than students with Paid classes.
# #### Average of Final Grades is high for students with paid classes as compared to students without paid classes.

# %% [markdown]
# ### Extra Curricular Activities Column

# %%
df_act=stud_mat[['G3','activities']].copy()

df_act1=df_act.groupby(['activities']).count()

df_act2=df_act.groupby(['activities']).mean()

print ('Number of Students with Respect to Extra activities \n', df_act1)
print ('\nAverage Final Grade of Students with Respect to Extra activities\n',df_act2,'\n\n')


#Plot

ax1 = df_act1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Extra activities vs Students", fontsize=15)
ax1.set_xlabel("activities", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_act2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Extra Activities vs Average G3", fontsize=15)
ax2.set_xlabel("activities", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Extra activities
#               G3
# activities
# no          194
# yes         201
#
# Average Final Grade of Students with Respect to Extra activities
#                     G3
# activities
# no          10.340206
# yes         10.487562

# %% [markdown]
# ### Findings:
# #### Number of students without activities are slightly less than students with activities.
# #### Average of Final Grades is slightly high for students with activities as compared to students without activities.

# %% [markdown]
# ### Nursery Column

# %%
df_nur=stud_mat[['G3','nursery']].copy()

df_nur1=df_nur.groupby(['nursery']).count()

df_nur2=df_nur.groupby(['nursery']).mean()

print ('Number of Students with Respect to Nursery \n', df_nur1)
print ('\nAverage Final Grade of Students with Respect to Nursery\n',df_nur2,'\n\n')


#Plot

ax1 = df_nur1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Nursery vs Students", fontsize=15)
ax1.set_xlabel("nursery", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_nur2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Nursery vs Average G3", fontsize=15)
ax2.set_xlabel("nursery", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Nursery
#            G3
# nursery
# no        81
# yes      314
#
# Average Final Grade of Students with Respect to Nursery
#                  G3
# nursery
# no        9.950617
# yes      10.535032

# %% [markdown]
# ### Findings:
# #### Number of students without Nursery are less than students with Nursery.
# #### Average of Final Grades is high for students with nursery as compared to students without nursery.

# %% [markdown]
# ### Higher Education Column

# %%
df_hedu=stud_mat[['G3','higher']].copy()

df_hedu1=df_hedu.groupby(['higher']).count()

df_hedu2=df_hedu.groupby(['higher']).mean()

print ('Number of Students with Respect to Higher education \n', df_hedu1)
print ('\nAverage Final Grade of Students with Respect to Higher Education\n',df_hedu2,'\n\n')


#Plot

ax1 = df_hedu1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Higher Education vs Students", fontsize=15)
ax1.set_xlabel("higher", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_hedu2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Higher Education vs Average G3", fontsize=15)
ax2.set_xlabel("higher", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Higher education
#           G3
# higher
# no       20
# yes     375
#
# Average Final Grade of Students with Respect to Higher Education
#              G3
# higher
# no       6.800
# yes     10.608

# %% [markdown]
# ### Findings:
# #### Number of students who wants to take higher education are more than students with do not want to take higher education.
# #### Average of Final Grades is high for students who wants to take higher education as compared to students who do not wants to take higher education.

# %% [markdown]
# ### Internet Column

# %%
df_int=stud_mat[['G3','internet']].copy()

df_int1=df_int.groupby(['internet']).count()

df_int2=df_int.groupby(['internet']).mean()

print ('Number of Students with Respect to Internet access \n', df_int1)
print ('\nAverage Final Grade of Students with Respect to Internet access\n',df_int2,'\n\n')


#Plot

ax1 = df_int1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Internet Access vs Students", fontsize=15)
ax1.set_xlabel("internet", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_int2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Internet Access vs Average G3", fontsize=15)
ax2.set_xlabel("internet", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Internet access
#             G3
# internet
# no         66
# yes       329
#
# Average Final Grade of Students with Respect to Internet access
#                   G3
# internet
# no         9.409091
# yes       10.617021

# %% [markdown]
# ### Findings:
# #### Number of students who has Internet access are more than students with do not have Internet.
# #### Average of Final Grades is high for students who have internet access as compared to students who do not have internet access.

# %% [markdown]
# ### Romantic Column

# %%
df_rom=stud_mat[['G3','romantic']].copy()

df_rom1=df_rom.groupby(['romantic']).count()

df_rom2=df_rom.groupby(['romantic']).mean()

print ('Number of Students with Respect to Romantic Relationship \n', df_rom1)
print ('\nAverage Final Grade of Students with Respect to Romantic Relationship\n',df_rom2,'\n\n')


#Plot

ax1 = df_rom1.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax1.set_title("Romantic Relationship vs Students", fontsize=15)
ax1.set_xlabel("romantic", fontsize=12)
ax1.set_ylabel("No. Students", fontsize=12)


ax2 = df_rom2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title("Romantic Relationship vs Average G3", fontsize=15)
ax2.set_xlabel("romantic", fontsize=12)
ax2.set_ylabel("Avg. G3", fontsize=12)

plt.show()
# Out:
# Number of Students with Respect to Romantic Relationship
#             G3
# romantic
# no        263
# yes       132
#
# Average Final Grade of Students with Respect to Romantic Relationship
#                   G3
# romantic
# no        10.836502
# yes        9.575758

# %% [markdown]
# ### Findings:
# #### Number of students who have romantic relationship are less than students with do not have romantic relationship.
# #### Average of Final Grades is high for students who do not have romantic relationship as compared to students who have romantic relationship.

# %% [markdown]
# ### Family Relationship Column

# %%
df_frel=stud_mat[['G3','famrel']].copy()

df_frel1=df_frel.groupby(['famrel']).count()
df_frel2=df_frel.groupby(['famrel']).mean()

print ('Number of Students with Respect to Family Relations\n',df_frel1)
print ('\nAverage Final Grade of Students with Respect to Family Relations\n',df_frel2,'\n\n')


#Plot

plt.plot(df_frel1)
plt.title('Family Relations vs No. Students', fontsize=15)
plt.xlabel('famrel', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_frel2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Family Relations vs Average G3', fontsize=15)
ax2.set_xlabel("famrel", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Family Relations
#           G3
# famrel
# 1         8
# 2        18
# 3        68
# 4       195
# 5       106
#
# Average Final Grade of Students with Respect to Family Relations
#                 G3
# famrel
# 1       10.625000
# 2        9.888889
# 3       10.044118
# 4       10.358974
# 5       10.830189

# %% [markdown]
# ### Findings:
# #### Number of students whose family relation is good are high as compared to students with bad family relation.
# #### Average of Final Grade is little bit unrelated because there are couple of ups & downs.

# %% [markdown]
# ### Free Time after School Column

# %%
df_ftm=stud_mat[['G3','freetime']].copy()

df_ftm1=df_ftm.groupby(['freetime']).count()
df_ftm2=df_ftm.groupby(['freetime']).mean()

print ('Number of Students with Respect to Free Time\n',df_ftm1)
print ('\nAverage Final Grade of Students with Respect to Free Time\n',df_ftm2,'\n\n')


#Plot

plt.plot(df_ftm1)
plt.title('Free Time vs No. Students', fontsize=15)
plt.xlabel('free time', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_ftm2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Free Time vs Average G3', fontsize=15)
ax2.set_xlabel("free time", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Free Time
#             G3
# freetime
# 1          19
# 2          64
# 3         157
# 4         115
# 5          40
#
# Average Final Grade of Students with Respect to Free Time
#                   G3
# freetime
# 1          9.842105
# 2         11.562500
# 3          9.783439
# 4         10.426087
# 5         11.300000

# %% [markdown]
# ### Findings
# #### Number of students who have free time of level '3' which is intermediate are more, followed by level '4', '2' & '5'
# #### Average of Final Grades is high for students having free time of level '2', followed by '5', '4' & '3'. This information is little bit unrelated.

# %% [markdown]
# ### Going Out Column

# %%
df_got=stud_mat[['G3','goout']].copy()

df_got1=df_got.groupby(['goout']).count()
df_got2=df_got.groupby(['goout']).mean()

print ('Number of Students with Respect to Going Out\n',df_got1)
print ('\nAverage Final Grade of Students with Respect to Going Out\n',df_got2,'\n\n')


#Plot

plt.plot(df_got1)
plt.title('Going out vs No. Students', fontsize=15)
plt.xlabel('go out', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_got2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Going out vs Average G3', fontsize=15)
ax2.set_xlabel("go out", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Going Out
#          G3
# goout
# 1       23
# 2      103
# 3      130
# 4       86
# 5       53
#
# Average Final Grade of Students with Respect to Going Out
#                G3
# goout
# 1       9.869565
# 2      11.194175
# 3      10.961538
# 4       9.651163
# 5       9.037736

# %% [markdown]
# ### Findings:
# #### Number of students who prefer to go out on level '3' are high followed level '2' & '4'.
# #### Average of Final Grades is slightly negatively correlated to Going Out.

# %% [markdown]
# ### Daily Alcohol Consumption Column

# %%
df_dalc=stud_mat[['G3','Dalc']].copy()

df_dalc1=df_dalc.groupby(['Dalc']).count()
df_dalc2=df_dalc.groupby(['Dalc']).mean()

print ('Number of Students with Respect to Daily Alcohol Consumption\n',df_dalc1)
print ('\nAverage Final Grade of Students with Respect to Daily Alcohol Consumption\n',df_dalc2,'\n\n')


#Plot

plt.plot(df_dalc1)
plt.title('Daily Alcohol vs No. Students', fontsize=15)
plt.xlabel('Dalc', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_dalc2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Daily Alcohol vs Average G3', fontsize=15)
ax2.set_xlabel("Dalc", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Daily Alcohol Consumption
#         G3
# Dalc
# 1     276
# 2      75
# 3      26
# 4       9
# 5       9
#
# Average Final Grade of Students with Respect to Daily Alcohol Consumption
#               G3
# Dalc
# 1     10.731884
# 2      9.253333
# 3     10.500000
# 4      9.888889
# 5     10.666667

# %% [markdown]
# ### Findings:
# #### Number of students are more who prefer to consume Daily Alcohol very less.
# #### Average of final grades is high for stduents who consume Daily Alcohol very less.

# %% [markdown]
# ### Weekdays Alcohol Consumptions Column

# %%
df_walc=stud_mat[['G3','Walc']].copy()

df_walc1=df_walc.groupby(['Walc']).count()
df_walc2=df_walc.groupby(['Walc']).mean()

print ('Number of Students with Respect to Weekend Alcohol Consumption\n',df_walc1)
print ('\nAverage Final Grade of Students with Respect to Weekend Alcohol Consumption\n',df_walc2,'\n\n')


#Plot

plt.plot(df_walc1)
plt.title('Weekend Alcohol vs No. Students', fontsize=15)
plt.xlabel('Walc', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_walc2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Weekend Alcohol vs Average G3', fontsize=15)
ax2.set_xlabel("Walc", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Weekend Alcohol Consumption
#         G3
# Walc
# 1     151
# 2      85
# 3      80
# 4      51
# 5      28
#
# Average Final Grade of Students with Respect to Weekend Alcohol Consumption
#               G3
# Walc
# 1     10.735099
# 2     10.082353
# 3     10.725000
# 4      9.686275
# 5     10.142857

# %% [markdown]
# ### Findings:
# #### Number of students are more who consumes less Alcohol in weekend.
# #### Also Average of final grades is high for stduents who consume weekly Alcohol less.

# %% [markdown]
# ### Health Column

# %%
df_hlt=stud_mat[['G3','health']].copy()

df_hlt1=df_hlt.groupby(['health']).count()
df_hlt2=df_hlt.groupby(['health']).mean()

print ('Number of Students with Respect to Health Conditions\n',df_hlt1)
print ('\nAverage Final Grade of Students with Respect to Health Conditions\n',df_hlt2,'\n\n')


#Plot

plt.plot(df_hlt1)
plt.title('Health Conditions vs No. Students', fontsize=15)
plt.xlabel('health', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_hlt2.plot(kind='bar',figsize=(8,5), legend=True, fontsize=12)
ax2.set_title('Health Conditions vs Average G3', fontsize=15)
ax2.set_xlabel("health", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Health Conditions
#           G3
# health
# 1        47
# 2        45
# 3        91
# 4        66
# 5       146
#
# Average Final Grade of Students with Respect to Health Conditions
#                 G3
# health
# 1       11.872340
# 2       10.222222
# 3       10.010989
# 4       10.106061
# 5       10.397260

# %% [markdown]
# ### Findings:
# #### Number of Students whose current health condition is very good are more.
# #### Average of Final grades is positively correlated to health conditions.

# %% [markdown]
# ### Absences Column

# %%
df_abs=stud_mat[['G3','absences']].copy()

df_abs1=df_abs.groupby(['absences']).count()
df_abs2=df_abs.groupby(['absences']).mean()

print ('Number of Students with Respect to Absences\n',df_abs1.head())
print ('\nAverage Final Grade of Students with Respect to Absences\n',df_abs2.head(),'\n\n')


#Plot
plt.rcParams['figure.figsize'] = [12, 4]
plt.plot(df_abs1)
plt.title('Absences vs No. Students', fontsize=15)
plt.xlabel('Absences', fontsize=12)
plt.ylabel('Students', fontsize=12)

ax2 = df_abs2.plot(kind='bar',figsize=(12,4), legend=True, fontsize=12)
ax2.set_title('Absences vs Average G3', fontsize=15)
ax2.set_xlabel("Absences", fontsize=15)
ax2.set_ylabel("G3 Average", fontsize=15)

plt.show()
# Out:
# Number of Students with Respect to Absences
#             G3
# absences
# 0         115
# 1           3
# 2          65
# 3           8
# 4          53
#
# Average Final Grade of Students with Respect to Absences
#                   G3
# absences
# 0          8.443478
# 1         13.000000
# 2         11.907692
# 3         11.500000
# 4         11.283019

# %% [markdown]
# ### Findings:
# #### Number of students are inversely proportional to absences, More students with '0' absences & very less students with '> 25' absences
# #### Average of Final Grades is little bit unrelated to number of absences.

# %% [markdown]
# ### Highly Correlated Numerical Column with respect to Final Grades 'G3'

# %%
# Correlation

stud_mat.corr()['G3'].sort_values()
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# ### Plotting Correlation Matrix

# %%
f, ax = plt.subplots(figsize=(12, 8))
corr=stud_mat.corr()

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### The correlation values & Matrix makes sense with respect to our Simple EDA. Except 'famrel', 'absence' & 'freetime'.
# #### we can see that 'G1' & 'G2' are very positively related to 'G3', also this makes sense because in data description it is stated that 'G3' is depended on 'G1' & 'G2'

# %% [markdown]
# ### Correlation between 'G1'

# %%
stud_mat.corr()['G1'].sort_values()
# Out:
# failures     -0.354718
# goout        -0.149104
# Walc         -0.126179
# Dalc         -0.094159
# traveltime   -0.093040
# health       -0.073172
# age          -0.064081
# absences     -0.031003
# freetime      0.012613
# famrel        0.022168
# studytime     0.160612
# Fedu          0.190270
# Medu          0.205341
# G3            0.801468
# G2            0.852118
# G1            1.000000
# Name: G1, dtype: float64

# %% [markdown]
# ### Correlation Between 'G2'

# %%
stud_mat.corr()['G2'].sort_values()
# Out:
# failures     -0.355896
# goout        -0.162250
# traveltime   -0.153198
# age          -0.143474
# health       -0.097720
# Walc         -0.084927
# Dalc         -0.064120
# absences     -0.031777
# famrel       -0.018281
# freetime     -0.013777
# studytime     0.135880
# Fedu          0.164893
# Medu          0.215527
# G1            0.852118
# G3            0.904868
# G2            1.000000
# Name: G2, dtype: float64

# %% [markdown]
# #### By taking look at both correlation values of 'G1' & 'G2', we found that:
# #### 'famrel' is positively related to 'G1' & Negatively related to 'G2'.
# #### 'freetime' is positively related to 'G1' & Negatively related to 'G2'.
# #### 'absences' is Negatively related to both 'G1' & 'G2'.
# ### Now this Information makes sense.

# %% [markdown]
# ### Correlation between categorical features

# %%
print ('\nAverage Final Grade of Students from each School\n',df_sch2)

print ('\nAverage Final Grade of Students with Respect to Sex\n',df_sex2)

print ('\nAverage Final Grade of Students From Urban & Rural\n',df_add2)

print ('\nAverage Final Grade of Students with Respect to Family Size\n',df_fsz2)

print ('\nAverage Final Grade of Students with Respect to Parents Cohabitation Status\n',df_pst2)

print ('\nAverage Final Grade of Students with Respect to Guardian\n',df_guar2)

print ('\nAverage Final Grade of Students with Respect to Extra Educational Support\n',df_ssup2)

print ('\nAverage Final Grade of Students with Respect to Family Support\n',df_fsup2)

print ('\nAverage Final Grade of Students with Respect to Extra paid Classes\n',df_paid2)

print ('\nAverage Final Grade of Students with Respect to Extra activities\n',df_act2)

print ('\nAverage Final Grade of Students with Respect to Nursery\n',df_nur2)

print ('\nAverage Final Grade of Students with Respect to Higher Education\n',df_hedu2)

print ('\nAverage Final Grade of Students with Respect to Internet access\n',df_int2)

print ('\nAverage Final Grade of Students with Respect to Romantic Relationship\n',df_rom2)
# Out:
# Average Final Grade of Students from each School
#                 G3
# school
# GP      10.489971
# MS       9.847826
#
# Average Final Grade of Students with Respect to Sex
#              G3
# sex
# F     9.966346
# M    10.914439
#
# Average Final Grade of Students From Urban & Rural
#                  G3
# address
# R         9.511364
# U        10.674267
#
# Average Final Grade of Students with Respect to Family Size
#                  G3
# famsize
# GT3      10.177936
# LE3      11.000000
#
# Average Final Grade of Students with Respect to Parents Cohabitation Status
#                  G3
# Pstatus
# A        11.195122
# T        10.324859
#
# Average Final Grade of Students with Respect to Guardian
#                   G3
# guardian
# father    10.688889
# mother    10.483516
# other      9.062500
#
# Average Final Grade of Students with Respect to Extra Educational Support
#                    G3
# schoolsup
# no         10.561047
# yes         9.431373
#
# ...

# %% [markdown]
# ### Findings:
# #### Among these all categorical features 'higher', 'internet' & 'romantic' columns shows noticeable relation between Final Grade 'G3'.

# %% [markdown]
# ### Lets check theses three columns relation with 'G1' & 'G2'

# %%
df_highg1=stud_mat[['G1','higher']].copy()
df_highg2=stud_mat[['G2','higher']].copy()

df_highg1=df_highg1.groupby(['higher']).mean()
df_highg2=df_highg2.groupby(['higher']).mean()

print ('\nAverage Final Grade of Students from each School\n',df_highg1)
print ('\nAverage Final Grade of Students from each School\n',df_highg2)


df_intg1=stud_mat[['G1','internet']].copy()
df_intg2=stud_mat[['G2','internet']].copy()

df_intg1=df_intg1.groupby(['internet']).mean()
df_intg2=df_intg2.groupby(['internet']).mean()

print ('\nAverage Final Grade of Students from each School\n',df_intg1)
print ('\nAverage Final Grade of Students from each School\n',df_intg2)

df_romg1=stud_mat[['G1','romantic']].copy()
df_romg2=stud_mat[['G2','romantic']].copy()

df_romg1=df_romg1.groupby(['romantic']).mean()
df_romg2=df_romg2.groupby(['romantic']).mean()


print ('\nAverage Final Grade of Students from each School\n',df_romg1)
print ('\nAverage Final Grade of Students from each School\n',df_romg2)
# Out:
# Average Final Grade of Students from each School
#                 G1
# higher
# no       8.350000
# yes     11.045333
#
# Average Final Grade of Students from each School
#                 G2
# higher
# no       7.800000
# yes     10.869333
#
# Average Final Grade of Students from each School
#                   G1
# internet
# no        10.378788
# yes       11.015198
#
# Average Final Grade of Students from each School
#                   G2
# internet
# no         9.712121
# yes       10.914894
#
# Average Final Grade of Students from each School
#                   G1
# romantic
# no        10.996198
# yes       10.734848
#
# Average Final Grade of Students from each School
#                   G2
# romantic
# no        11.011407
# yes       10.121212

# %% [markdown]
# ### Findings:
# #### Categorical feature 'higher' shows more relation between 'G1' & 'G2'. Because difference between 'higher-yes' & 'higher-no' is quite big for both 'G1' & 'G2'.

# %% [markdown]
# ### Visualize Density of 'higher' for 'G1' & 'G2'

# %%
sns.kdeplot(stud_mat.loc[stud_mat['higher'] == 'yes', 'G1'], label = 'Yes', shade = True)
sns.kdeplot(stud_mat.loc[stud_mat['higher'] == 'no', 'G1'], label = 'NO', shade = True)
plt.xlabel('G1')
plt.ylabel('Density')
plt.title('Density Plot of G1')
# Out:
# Text(0.5,1,'Density Plot of G1')

# %%
sns.kdeplot(stud_mat.loc[stud_mat['higher'] == 'yes', 'G2'], label = 'Yes', shade=True)
sns.kdeplot(stud_mat.loc[stud_mat['higher'] == 'no', 'G2'], label = 'NO', shade=True)
plt.xlabel('G2')
plt.ylabel('Density')
plt.title('Density Plot of G2')
# Out:
# Text(0.5,1,'Density Plot of G2')

# %% [markdown]
# ### Here we got required knowledge about our Data & Target.

# %% [markdown]
# ## Lets Begin Model Building
# ### We will use Multiple Linear Regression
# ### Approach (Cascaded Multiple Linear Regression):
# #### - Build First Multiple Linear Regression Model with target 'G1' & 'G2'
# #### - Build Second Multiple Linear Regression Model by predictors 'G1' & 'G2' and target value 'G3'.

# %% [markdown]
# ### Creating DataFrame to Predict 'G1'

# %%
dataset1 = stud_mat[['age', 'Medu','Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime',
                     'goout', 'Dalc', 'Walc', 'health', 'absences', 'higher', 'G1']].copy()

dataset1.replace('yes', 1, inplace=True)
dataset1.replace('no', 0, inplace=True)

dataset1.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  higher  G1
# 0     1     1       3         6       1   5
# 1     1     1       3         4       1   5
# 2     2     3       3        10       1   7
# 3     1     1       5         2       1  15
# 4     1     2       5         4       1   6

# %%
# Generating Predictors and Response arrays

X1 = dataset1.iloc[:, :-1].values  
y1 = dataset1.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  

# Splitting Data into Train & Test sets

X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=0)

# %%
# Fitting Linear Regression Model

regressor1 = LinearRegression()  

regressor1.fit(X_train1, y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Predicting values for Test Dataset

y_pred1 = regressor1.predict(X_test1)  

df1 = pd.DataFrame({'Actual': y_test1, 'Predicted': y_pred1})

df1.head()
# Out:
#    Actual  Predicted
# 0       4        4.0
# 1       3        3.0
# 2       4        4.0
# 3       4        4.0
# 4       4        4.0

# %% [markdown]
# ### Metrics for Evaluating Model Performance

# %%
from sklearn import metrics

mae = metrics.mean_absolute_error(y_test1, y_pred1)
print('Mean Absolute Error:', mae)  

mse = metrics.mean_squared_error(y_test1, y_pred1)
print('Mean Squared Error:', mse)

rmse = np.sqrt(metrics.mean_squared_error(y_test1, y_pred1))
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 9.42372104654819e-15
# Mean Squared Error: 3.2709503631591826e-28
# Root Mean Squared Error: 1.8085768889265345e-14

# %% [markdown]
# ### First Model Performance to Predict 'G1':
# #### Mean Absolute Error: 9.42
# #### Mean Squared Error: 3.27
# #### Root Mean Squared Error: 1.80

# %% [markdown]
# ### Creating Dataset & Building Model to Predict 'G2'

# %%
dataset2 = stud_mat[['age', 'Medu','Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime',
                     'goout', 'Dalc', 'Walc', 'health', 'absences', 'higher', 'G2']].copy()

dataset2.replace('yes', 1, inplace=True)
dataset2.replace('no', 0, inplace=True)


X2 = dataset2.iloc[:, :-1].values  
y2 = dataset2.iloc[:, 1].values  

# Splitting Data
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=0)  

#Fitting Model
regressor2 = LinearRegression()  
regressor2.fit(X_train2, y_train2)

#Predicting
y_pred2 = regressor2.predict(X_test2)  

df2 = pd.DataFrame({'Actual': y_test2, 'Predicted': y_pred2})

df2.head()
# Out:
#    Actual  Predicted
# 0       4        4.0
# 1       3        3.0
# 2       4        4.0
# 3       4        4.0
# 4       4        4.0

# %% [markdown]
# ### Metrics for Evaluating Performance of Model

# %%
mae = metrics.mean_absolute_error(y_test2, y_pred2)
print('Mean Absolute Error:', mae)  

mse = metrics.mean_squared_error(y_test2, y_pred2)
print('Mean Squared Error:', mse)

rmse = np.sqrt(metrics.mean_squared_error(y_test2, y_pred2))
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 9.42372104654819e-15
# Mean Squared Error: 3.2709503631591826e-28
# Root Mean Squared Error: 1.8085768889265345e-14

# %% [markdown]
# ### First Model Performance to Predict 'G2':
# #### Mean Absolute Error: 9.42
# #### Mean Squared Error: 3.27
# #### Root Mean Squared Error: 1.80

# %% [markdown]
# ### Creating Dataset & Model to predict G3

# %%
dataset3 = stud_mat[['G1', 'G2', 'G3']].copy()


X3 = dataset3.iloc[:, :-1].values  
y3 = dataset3.iloc[:, 1].values  


X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.2, random_state=0)  

regressor3 = LinearRegression()  
regressor3.fit(X_train3, y_train3)

y_pred3 = regressor3.predict(X_test3) 


df = pd.DataFrame({'Actual': y_test3, 'Predicted': y_pred3})  
df.head()
# Out:
#    Actual  Predicted
# 0      14       14.0
# 1      11       11.0
# 2      10       10.0
# 3      15       15.0
# 4      16       16.0

# %% [markdown]
# ### Metrics for evaluating Model Performance

# %%
mae = metrics.mean_absolute_error(y_test3, y_pred3)
print('Mean Absolute Error:', mae)  

mse = metrics.mean_squared_error(y_test3, y_pred3)
print('Mean Squared Error:', mse)

rmse = np.sqrt(metrics.mean_squared_error(y_test3, y_pred3))
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 7.672760550102722e-16
# Mean Squared Error: 1.7009926690287494e-30
# Root Mean Squared Error: 1.3042210966813676e-15

# %% [markdown]
# ### Model Performance to Predict 'G2':
# #### Mean Absolute Error: 7.67
# #### Mean Squared Error: 1.70
# #### Root Mean Squared Error: 1.30

# %% [markdown]
# ## Lets do some Model Tunning with Feature Selection
# #### We will use 'Medu','Fedu', 'studytime', 'failures', 'goout', 'higher', to predict 'G1'

# %%
dataset4 = stud_mat[['Medu','Fedu', 'studytime', 'failures', 'goout', 'higher', 'G1']].copy()

dataset4.replace('yes', 1, inplace=True)
dataset4.replace('no', 0, inplace=True)

dataset4.head()
# Out:
#    Medu  Fedu  studytime  failures  goout  higher  G1
# 0     4     4          2         0      4       1   5
# 1     1     1          2         0      3       1   5
# 2     1     1          2         3      2       1   7
# 3     4     2          3         0      2       1  15
# 4     3     3          2         0      2       1   6

# %%
X4 = dataset4.iloc[:, :-1].values  
y4 = dataset4.iloc[:, 1].values  

X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.2, random_state=0)  

regressor4 = LinearRegression()  
regressor4.fit(X_train4, y_train4)

y_pred4 = regressor4.predict(X_test4)  

df = pd.DataFrame({'Actual': y_test4, 'Predicted': y_pred4})  
#df.head()

mae = metrics.mean_absolute_error(y_test4, y_pred4)
print('Mean Absolute Error:', mae)  

mse = metrics.mean_squared_error(y_test4, y_pred4)
print('Mean Squared Error:', mse)

rmse = np.sqrt(metrics.mean_squared_error(y_test4, y_pred4))
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 7.234478111543002e-16
# Mean Squared Error: 8.782721497694663e-31
# Root Mean Squared Error: 9.371617521908725e-16

# %% [markdown]
# ### Performance by using all features
# #### Mean Absolute Error : 9.42
# #### Mean Squared Error: 3.27
# #### Root Mean Squared Error: 1.80
#
# ### Performance without using all features
# #### Mean Absolute Error : 7.23
# #### Mean Squared Error: 8.78
# #### Root Mean Squared Error: 9.37

# %% [markdown]
# ### This results clearly shows evidence that Model with all features works best

# %% [markdown]
# ### So we going to use:
# #### 'regressor1' to predict 'G1'
# #### 'regressor2' to predict 'G2
# #### regressor3' to Predict 'G3'

# %% [markdown]
# ## Testing Model on Random Data

# %% [markdown]
# ### Pass values in following dataframe to predict 'G1'

# %%
g1 = {
    'age':[18], #PASS AGE
     'Medu':[4], #PASS MEDU
     'Fedu':[4], 
     'traveltime':[2],
     'studytime':[2], 
     'failures':[0], 
     'famrel':[4], 
     'freetime':[3],
     'goout':[4], 
     'Dalc':[1], 
     'Walc':[1], 
     'health':[3], 
     'absences':[6], 
     'higher':[1] # 0 for 'No' & 1 for 'Yes'
    }

test_g1 = pd.DataFrame(data=g1)
test_g1
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
#
#    Dalc  Walc  health  absences  higher
# 0     1     1       3         6       1

# %% [markdown]
# ### Pass values in following dataframe to predict 'G2'

# %%
g2 = {
    'age':[18], #PASS AGE
     'Medu':[4], #PASS MEDU
     'Fedu':[4], 
     'traveltime':[2],
     'studytime':[2], 
     'failures':[0], 
     'famrel':[4], 
     'freetime':[3],
     'goout':[4], 
     'Dalc':[1], 
     'Walc':[1], 
     'health':[3], 
     'absences':[6], 
     'higher':[1] # 0 for 'No' & 1 for 'Yes'
    }

test_g2 = pd.DataFrame(data=g2)
test_g2
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
#
#    Dalc  Walc  health  absences  higher
# 0     1     1       3         6       1

# %% [markdown]
# ### Predicting 'G3' on basis of Predicted 'G1' & 'G2'

# %%
#Predicting 'G1'

X5 = test_g1.iloc[:, :].values  

y_pred5 = regressor1.predict(X5)  

print ('predicted G1:',y_pred5[0])


#Predicting 'G2'

X6 = test_g2.iloc[:, :].values  

y_pred6 = regressor2.predict(X6)  

print ('predicted G2:',y_pred6[0])


#Predicting 'G3' by passing predicted 'G1' & 'G2'

d = {'G1':y_pred5,'G2':y_pred6}

test_g3 = pd.DataFrame(d)

X7 = test_g3.iloc[:, :].values  

y_pred7 = regressor3.predict(X7)
# Out:
# predicted G1: 3.9999999999999987
# predicted G2: 3.9999999999999987

# %% [markdown]
# # Final Prediction Results

# %%
print ('predicted G3:',y_pred7[0],'\n\n')

if y_pred7[0] >= 10:
    print ('Student will PASS')
    
else:
    print ('Student will FAIL')
# Out:
# predicted G3: 4.0
#
#
# Student will FAIL

# %% [markdown]
# ## Now we will Use Random Forest Algorithm to Predict 'G3'
#
# ### Because our Final Grades 'G3' output ranges between 0 - 20
# ### So Trees will help us to predict Final Grades more precisely & will perform better than Multiple Linear Regression.
